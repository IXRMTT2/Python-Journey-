# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv('../../ailearningcourseudemy/TF_2_Notebooks_and_Data/01-Pandas-Crash-Course/heart.csv')

# %%
sns.distplot(df['age'],kde=False)

# %%
plt.figure(figsize=(15,15))
sns.distplot(df['age'],kde=False,color='red')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
sns.countplot(x='cp',data=df, hue='sex')

# %%
 sns.boxplot(x='cp',y='age',data=df,hue='sex')

# %%
sns.scatterplot(x='chol',y='trestbps',data=df,hue='sex',palette='Dark2',size='age')
